# %%
import pandas as pd

df = pd.read_csv('data.csv')

print(df.to_string())
# Out:
#                           username  rating                                                                                                                                                                                                                                                                                                                           comment
# 0                       3629pkcerq       5                                                                                                                                                                                                                                                             Hình ảnh chỉ mang tc nhận xu, mn nên mua nha hợp giá tiền, chất okela
# ...

# %%
print(df.head(10))
# Out:
#               username  rating  \
# 0           3629pkcerq       5
# 1              b*****8       5
# 2              m*****2       5
# 3              n*****u       5
# 4              p*****8       5
# 5           anhthu8761       5
# 6     thuydung19129995       5
# 7           lan1291999       5
# 8  phanthitragiang2208       5
# 9              b*****6       5
#
#                                              comment
# 0  Hình ảnh chỉ mang tc nhận xu, mn nên mua nha h...
# 1  Mua ở shop 2 lần rồi , giao đúng số lượng , ch...
# 2  Vải quần ổn. Quần như hình \nĐóng gói sp cẩn t...
# 3  Vải k mỏng cũng k dày. Vải túi  quần k giống m...
# 4  Chất vải khá ổn, giao hàng cũng nhanh,...........
# 5  Quần xinh cực luôn ắ mn rẻ mà chất lượng giao ...
# 6  quần vải đẹp chất mịn.Đã giặt rồi mặc lên from...
# 7  Hình ảnh mang tính chất nhận xu \nQuần đẹp lắm...
# 8  Sorry hình ảnh k liên quan. \nMình mua đồ lần ...
# 9  Quần đẹp lắm nha mọi người ơiiii, chất vải siê...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3020 entries, 0 to 3019
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   username  3011 non-null   object
#  1   rating    3020 non-null   int64
#  2   comment   2567 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 70.9+ KB
# None

# %%
df = pd.read_csv('data.csv')

new_df = df.dropna(inplace = True          )

print(new_df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/ry/fl6jbxp15x5b06f5y55956z80000gn/T/ipykernel_4639/4277721278.py in <module>
#       3 new_df = df.dropna(inplace = True          )
#       4
# ----> 5 print(new_df.head())
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
DJS6emtdrmL9dSK9
